# %%
import re
import os

import pyedflib
import numpy as np
import pandas as pd


import csv

from scipy.signal import resample
from utils_pipeline import Pipeline
from preprocessing_library import FFT, Slice, Magnitude, Log10

# %%
! which python
# Out:
# /home/eshuranov/miniconda3/envs/py38/bin/python

# %% [markdown]
# ### Constructing the dictionary with labels

# %%
class Preprocess:
    @staticmethod
    def merge(segments):
        """
        :param segments: list of overlapping intervals with same label, segment[i][0] - start, segment[i][1] - end
        :return: list of intervals with no overlaps
        """
        merged = []
        segments.sort(key=lambda x: x[0])

        for segment in segments:
            if not merged or segment[0] > merged[-1][1]:
                merged.append(segment)
            else:
                merged[-1][1] = segment[1]

        return merged

    def labeling(self, intervals):
        """
        :param intervals: list of intervals where intervals[i][0] - start intervals[i][1] - end intervals[i][2] - label
        :return: labels - dictionary, keys - labels, values - intervals
        """
        labels = {}

        for interval in intervals:
            if interval[-1] not in labels:
                labels[interval[-1]] = [interval[0]]
            else:
                labels[interval[-1]].append(interval[0])

        # print(labels)
        for key in labels:
            labels[key] = self.merge(labels[key])

        return labels

    def apply_one_file(self, file_path):
        """
        :params: file_path - path to a single file
        :return: result - dictionary with the following structure: file_name -> channel -> lable -> intervals with no overlaps
        """
        result = {}
        dct = {}
        with open(file_path, 'r') as file:
            for node in file.readlines():
                node = node[:-1]

                node = node.split(',')

                if int(node[0]) not in dct:
                    dct[int(node[0])] = [[[float(node[1]), float(node[2])], int(node[3])]]
                else:
                    dct[int(node[0])].append([[float(node[1]), float(node[2])], int(node[3])])

            for key in dct:
                dct[key] = self.labeling(dct[key])
    
            result[file_path[:-4]] = dct
        
        return result
        
    def apply_dataset(self):
        """
        apply the labeling to the whole directory
        """
        result = {}
        
        for root, dirs, files in os.walk("/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train", topdown=True):
            for name in files:
                if name.endswith('.rec'):
                    file_path = os.path.join(root, name)

                    dct = {}
                    """
                    node[0] - chanel
                    node[1] - start
                    node[2] - end
                    node[3] - label
                    """
                    with open(file_path, 'r') as file:
                        for node in file.readlines():
                            node = node[:-1]

                            node = node.split(',')

                            if int(node[0]) not in dct:
                                dct[int(node[0])] = [[[round(float(node[1]), 4), round(float(node[2]), 4)], int(node[3])]]
                            else:
                                dct[int(node[0])].append([[round(float(node[1]), 4), round(float(node[2]), 4)], int(node[3])])

                    for key in dct:
                        dct[key] = self.labeling(dct[key])

                    result[file_path[:-4]] = dct
        return result

# %% [markdown]
# ### Analysing the dictionary with labels

# %%
label_dct = Preprocess().apply_dataset()

# %%
print("label_dct: ",label_dct)
# Out:
# label_dct:  {'/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaaehl/aaaaaehl_00000001': {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]},
/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaaclp/aaaaaclp_00000002': {6: {6: [[0.2, 10.2]]}, 9: {6: [[0.2, 10.2]]}, 16: {6: [[0.2, 10.2]]}, 8: {6: [[0.2, 10.2]]}, 17: {6: [[0.2, 10.2]]}, 12: {6: [[0.2, 10.2]]}, 13: {6: [[0.2, 10.2]]}, 10: {6: [[0.2, 10.2]]}, 4: {6: [[0.2, 10. ...

# %%
cnt_int = 0
cnt_float = 0

for file_name in label_dct.keys():
    for channel in sorted(label_dct[file_name].keys()):
        for label in sorted(label_dct[file_name][channel].keys()):
            for interval in label_dct[file_name][channel][label]:
                if (interval[1] - interval[0]) % 1 == 0:
                    cnt_int += 1
                else:
                    cnt_float += 1

print(cnt_int)
print(cnt_float)
# Out:
# 17234
# 2228

# %% [markdown]
# ### Constructing numpy files for a single edf file

# %%
test_file_path_rec = '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaablw/aaaaablw_00000001.rec'
single_file_dct = Preprocess().apply_one_file(test_file_path_rec)
single_file_dct
# Out:
# {'/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaablw/aaaaablw_00000001': {6: {6: [[29.1,
#      38.1],
#     [57.7, 65.7]]},
#   9: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   20: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   15: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   1: {6: [[29.1, 38.1]]},
#   11: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   2: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   21: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   14: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   10: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   12: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   19: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   8: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   0: {6: [[29.1, 38.1]]},
#   13: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   5: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   16: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   18: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   3: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   17: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   7: {6: [[29.1, 38.1], [57.7, 65.7]]},
#   4: {6: [[29.1, 38.1], [57.7, 65.7]]}}}

# %% [markdown]
# ### Extracting signals

# %%
parameters = pd.read_csv('/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/parameters.csv', index_col=['parameter'])

# %%
def extract_signal(f, signal_labels, electrode_name, start, stop):
    """
    f - opened edf file.
    signal_labels - list of signals.
    electrode_name - the name of electrode.
    start - start of the window in seconds.
    stop - end of the window in seconds.
    """
    tuh_label = [s for s in signal_labels if 'EEG ' + electrode_name + '-' in s]
    if len(tuh_label) > 1:
        print(tuh_label)
        exit('Multiple electrodes found with the same string! Abort')
        
    channel = signal_labels.index(tuh_label[0])
    signal = np.array(f.readSignal(channel))

    return signal[start:stop]

# %% [markdown]
# ### Constructing FFT images

# %%
def convert_to_fft(window_start, window_end, window_step, channel,
                               fft_min_freq, fft_max_freq, sampling_frequency, file_path):
    """
    Split an interval into 1 second intervals with 0.5 second overlap, applying FFT.
    
    parmas:
    window_start - the beginning of interval in seconds.
    window_end - the end of interval in seconds.
    window_step - the overlap in seconds.
    channel - 
    fft_min_freq - the min frequency.
    fft_max_freq - the max ferquency.
    sampling_ferquency - the frequency of the edf file.
    file_path - the path to the edf file.
    
    return:
    np.array - interval splitted into 1 secons segments with 0.5 second overlap, with FFT applied.
    """
    pipeline = Pipeline([FFT(), Slice(fft_min_freq, fft_max_freq), Magnitude(), Log10()])
    
    start, step = int(np.floor(window_start * sampling_frequency)), int(np.floor(window_step * sampling_frequency))
    stop = start + step

    lst = file_path.split('/')
    file_name = lst[-1][:-4]
    fft_data = []

    montage = str(parameters.loc['montage']['value'])
    montage_list = re.split(';', montage)
    print("montage_list: ", montage_list)
    print("montage_list[channel]: ", montage_list[channel])
    electrode_list = re.split('-', montage_list[channel])

    f = pyedflib.EdfReader(file_path)
    signal_labels = f.getSignalLabels()
    
    while stop <= window_end * sampling_frequency:
        extracted_signal_from_electrode_1 = extract_signal(f, signal_labels, electrode_list[0], start, stop)
        extracted_signal_from_electrode_2 = extract_signal(f, signal_labels, electrode_list[1], start, stop)
        
        signal_window = np.array(extracted_signal_from_electrode_1-extracted_signal_from_electrode_2)
        fft_window = pipeline.apply(signal_window)
        
        fft_data.append(fft_window)
        start, stop = start + step, stop + step
        # print(fft_data)
    
    f._close()
    del f
    
    return np.array(fft_data)

# %% [markdown]
# ### A single file usage example

# %%
test_file_path_edf = '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaablw/aaaaablw_00000001.edf'
arr = convert_to_fft(29.1, 38.1, 0.5, 0, 1, 96, 250, test_file_path_edf)
print(f'arr: {arr},\nlen(arr): {len(arr)},\nlen(arr[0]): {len(arr[0])}')
# Out:
# arr: [[1.71065759 1.63976    0.7138609  ... 1.18646985 1.2437725  0.78738767]
#  [2.1504314  1.75372405 1.93814755 ... 1.26149422 1.15614055 1.03361897]
#  [2.42635049 1.64645036 2.12363506 ... 1.15438603 1.41452648 1.26861089]
#  ...
#  [2.17775443 2.04387071 1.9346262  ... 1.09226038 1.28243374 1.14905439]
#  [2.24846638 2.50624815 1.5401735  ... 1.49119303 0.95360965 1.16301862]
#  [2.20585812 1.91174881 1.93668347 ... 1.04818828 0.94269498 0.78888465]],
# len(arr): 18,
# len(arr[0]): 62

# %% [markdown]
# ### Multiple-files usage example

# %%
unique_id = 0
out_path = "/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/"
list_of_rows = []
for file_name in list(label_dct.keys())[:3]: # constructing the numpy files for the first 3 files
    print(file_name)
    wkspFldr = (file_name.split('/')[0:-1])
    # print("wkspFldr: ",wkspFldr)
    
    fname = os.path.basename(file_name)
    # out_name = out_path + "/" + wkspFldr[-1]+"//" + fname
    out_name = out_path + fname
    print("out_name: ",out_name)
    # continue
    for channel in range(22): 
        try: # sometimes there is no data about a channel
            print("channel:",channel)
            print("qq",label_dct[file_name])
            
            for label in label_dct[file_name][channel]:
                for index, interval in enumerate(label_dct[file_name][channel][label]):
                    result_file_name = out_name + '_channel_' + str(channel) + '_label_' + str(label) + '_interval_id_' + str(index) + '_unique_id_' + str(unique_id)
                    unique_id += 1
                    
                    if len(interval) > 1:
                        print("interval: ",interval, label, index, unique_id)
                        arr = convert_to_fft(interval[0], interval[1], 0.5, channel, 1, 96, 250, file_name + '.edf')
                        print("result_file_name: ",result_file_name)
                        np.save(result_file_name, arr)
                        d_tmp={}
                        d_tmp["fname"]=fname
                        d_tmp["channel"]=channel
                        d_tmp["label"]=label
                        d_tmp["interval"]=interval
                        d_tmp["unique_id"] = unique_id
                        d_tmp["path"] = result_file_name+".npy"
                        list_of_rows.append(d_tmp)
                    # break
                # break      
        
        except KeyError as exx:
            print(exx)
            pass
        # break
    
    print("list_of_rows: ",list_of_rows)
    print("list_of_rows 0 : ",list_of_rows[0])

    keys = list_of_rows[0].keys()
    with open(out_path+'row_list.csv', 'w', newline='') as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(list_of_rows)
# Out:
# /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaaehl/aaaaaehl_00000001
# out_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001
# channel: 0
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 18: {1: [[28.7, 29.7]]}, 7: {6: [[31.1, 35.1]]}, 17: {1: [[28.7, 29.7]]}, 12: {6: [[31.1, 35.1]]}, 2: {1: [[28.7, 29.7]]}, 10: {6: [[31.1, 35.1]]}, 16: {1: [[28.7, 29.7]]}}
# 0
# channel: 1
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 18: {1: [[28.7, 29.7]]}, 7: {6: [[31.1, 35.1]]}, 17: {1: [[28.7, 29.7]]}, 12: {6: [[31.1, 35.1]]}, 2: {1: [[28.7, 29.7]]}, 10: {6: [[31.1, 35.1]]}, 16: {1: [[28.7, 29.7]]}}
# interval:  [28.7, 29.7] 1 0 1
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F7-T3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_1_label_1_interval_id_0_unique_id_0
# channel: 2
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]},
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_18_label_1_interval_id_0_unique_id_16
# channel: 19
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 18: {1: [[28.7, 29.7]]}, 7: {6: [[31.1, 35.1]]}, 17: {1: [[28.7, 29.7]]}, 12: {6: [[31.1, 35.1]]}, 2: {1: [[28.7, 29.7]]}, 10: {6: [[31.1, 35.1]]}, 16: {1: [[28.7, 29.7]]}}
# interval:  [28.7, 29.7] 1 0 18
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_19_label_1_interval_id_0_unique_id_17
# channel: 20
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 18: {1: [[28.7, 29.7]]}, 7: {6: [[31.1, 35.1]]}, 17: {1: [[28.7, 29.7]]}, 12: {6: [[31.1, 35.1]]}, 2: {1: [[28.7, 29.7]]}, 10: {6: [[31.1, 35.1]]}, 16: {1: [[28.7, 29.7]]}}
# 20
# channel: 21
# qq {8: {6: [[31.1, 35.1]]}, 15: {1: [[28.7, 29.7]]}, 1: {1: [[28.7, 29.7]]}, 4: {6: [[31.1, 35.1]]}, 5: {6: [[31.1, 35.1]]}, 6: {6: [[31.1, 35.1]]}, 11: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 19: {1: [[28.7, 29.7]]}, 9: {1: [[28.8, 29.8]], 6: [[31.1, 35.1]]}, 18: {1: [[28.7, 29.7]]}, 7: {6: [[31.1, 35.1]]}, 17: {1: [[28.7, 29.7]]}, 12: {6: [[31.1, 35.1]]}, 2: {1: [[28.7, 29.7]]}, 10: {6: [[31.1, 35.1]]}, 16: {1: [[28.7, 29.7]]}}
# 21
# list_of_rows:  [{'fname': 'aaaaaehl_00000001', 'channel': 1, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 1, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_1_label_1_interval_id_0_unique_id_0.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 2, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 2, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_2_label_1_interval_id_0_unique_id_1.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 4, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 3, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_4_label_6_interval_id_0_unique_id_2.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 5, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 4, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_5_label_6_interval_id_0_unique_id_3.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 6, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 5, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_6_label_6_interval_id_0_unique_id_4.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 7, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 6, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_7_label_6_interval_id_0_unique_id_5.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 8, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 7, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_8_label_6_interval_id_0_unique_id_6.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 9, 'label': 1, 'interval': [28.8, 29.8], 'unique_id': 8, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_9_label_1_interval_id_0_unique_id_7.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 9, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 9, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_9_label_6_interval_id_0_unique_id_8.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 10, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 10, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_10_label_6_interval_id_0_unique_id_9.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 11, 'label': 1, 'interval': [28.8, 29.8], 'unique_id': 11, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_11_label_1_interval_id_0_unique_id_10.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 11, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 12, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_11_label_6_interval_id_0_unique_id_11.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 12, 'label': 6, 'interval': [31.1, 35.1], 'unique_id': 13, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_12_label_6_interval_id_0_unique_id_12.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 15, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 14, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_15_label_1_interval_id_0_unique_id_13.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 16, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 15, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_16_label_1_interval_id_0_unique_id_14.npy'}, {'fname': 'aaaaaehl_00000001', 'channel': 17, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 16, 'path': '/home/eshuranov/projects/eeg_epileptiform ...
# list_of_rows 0 :  {'fname': 'aaaaaehl_00000001', 'channel': 1, 'label': 1, 'interval': [28.7, 29.7], 'unique_id': 1, 'path': '/home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaehl_00000001_channel_1_label_1_interval_id_0_unique_id_0.npy'}
# /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/TUEV/tuev/edf/train/aaaaaaoy/aaaaaaoy_00000001
# out_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001
# channel: 0
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 19
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP1-F7
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_0_label_5_interval_id_0_unique_id_18
# interval:  [559.5, 563.5] 5 1 20
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP1-F7
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_0_label_5_interval_id_1_unique_id_19
# interval:  [6.9, 7.9] 4 0 21
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP1-F7
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_0_label_4_interval_id_0_unique_id_20
# channel: 1
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 22
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F7-T3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_1_label_5_interval_id_0_unique_id_21
# interval:  [6.9, 7.9] 5 1 23
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F7-T3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_1_label_5_interval_id_1_unique_id_22
# interval:  [559.5, 563.5] 5 2 24
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F7-T3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_1_label_5_interval_id_2_unique_id_23
# channel: 2
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 25
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T3-T5
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_2_label_5_interval_id_0_unique_id_24
# interval:  [559.5, 563.5] 5 1 26
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T3-T5
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_2_label_5_interval_id_1_unique_id_25
# channel: 3
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 27
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T5-O1
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_3_label_5_interval_id_0_unique_id_26
# interval:  [559.5, 563.5] 5 1 28
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T5-O1
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_3_label_5_interval_id_1_unique_id_27
# interval:  [546.7, 551.7] 6 0 29
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T5-O1
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_3_label_6_interval_id_0_unique_id_28
# channel: 4
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 30
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F8
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_4_label_5_interval_id_0_unique_id_29
# interval:  [559.5, 563.5] 5 1 31
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F8
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_4_label_5_interval_id_1_unique_id_30
# interval:  [546.7, 551.7] 6 0 32
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F8
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_4_label_6_interval_id_0_unique_id_31
# channel: 5
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 33
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F8-T4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_5_label_5_interval_id_0_unique_id_32
# interval:  [559.5, 563.5] 5 1 34
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F8-T4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_5_label_5_interval_id_1_unique_id_33
# interval:  [546.7, 551.7] 6 0 35
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F8-T4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_5_label_6_interval_id_0_unique_id_34
# channel: 6
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 36
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T4-T6
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_6_label_5_interval_id_0_unique_id_35
# interval:  [559.5, 563.5] 5 1 37
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T4-T6
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_6_label_5_interval_id_1_unique_id_36
# interval:  [546.7, 551.7] 6 0 38
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T4-T6
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_6_label_6_interval_id_0_unique_id_37
# channel: 7
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 39
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T6-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_7_label_5_interval_id_0_unique_id_38
# interval:  [559.5, 563.5] 5 1 40
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T6-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_7_label_5_interval_id_1_unique_id_39
# interval:  [546.7, 551.7] 6 0 41
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T6-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_7_label_6_interval_id_0_unique_id_40
# channel: 8
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 42
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T3-C3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_8_label_5_interval_id_0_unique_id_41
# interval:  [2.8, 6.8] 5 1 43
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T3-C3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_8_label_5_interval_id_1_unique_id_42
# interval:  [559.5, 563.5] 5 2 44
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  T3-C3
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_8_label_5_interval_id_2_unique_id_43
# channel: 9
# ...
# montage_list[channel]:  FP2-F4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_16_label_5_interval_id_0_unique_id_71
# interval:  [559.5, 563.5] 5 1 73
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_16_label_5_interval_id_1_unique_id_72
# interval:  [2.7, 6.7] 6 0 74
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_16_label_6_interval_id_0_unique_id_73
# interval:  [542.3, 546.3] 6 1 75
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_16_label_6_interval_id_1_unique_id_74
# interval:  [546.6, 552.6] 6 2 76
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  FP2-F4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_16_label_6_interval_id_2_unique_id_75
# channel: 17
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 77
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F4-C4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_17_label_5_interval_id_0_unique_id_76
# interval:  [559.5, 563.5] 5 1 78
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F4-C4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_17_label_5_interval_id_1_unique_id_77
# interval:  [2.7, 6.7] 6 0 79
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F4-C4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_17_label_6_interval_id_0_unique_id_78
# interval:  [542.3, 546.3] 6 1 80
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F4-C4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_17_label_6_interval_id_1_unique_id_79
# interval:  [546.6, 552.6] 6 2 81
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  F4-C4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_17_label_6_interval_id_2_unique_id_80
# channel: 18
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 82
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_5_interval_id_0_unique_id_81
# interval:  [559.5, 563.5] 5 1 83
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_5_interval_id_1_unique_id_82
# interval:  [2.7, 6.7] 6 0 84
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_6_interval_id_0_unique_id_83
# interval:  [542.3, 546.3] 6 1 85
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_6_interval_id_1_unique_id_84
# interval:  [546.6, 552.6] 6 2 86
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_6_interval_id_2_unique_id_85
# interval:  [6.8, 7.8] 4 0 87
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  C4-P4
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_18_label_4_interval_id_0_unique_id_86
# channel: 19
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 88
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_19_label_5_interval_id_0_unique_id_87
# interval:  [559.5, 563.5] 5 1 89
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_19_label_5_interval_id_1_unique_id_88
# interval:  [2.7, 6.7] 6 0 90
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_19_label_6_interval_id_0_unique_id_89
# interval:  [542.3, 546.3] 6 1 91
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_19_label_6_interval_id_1_unique_id_90
# interval:  [546.6, 552.6] 6 2 92
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# montage_list[channel]:  P4-O2
# result_file_name:  /home/eshuranov/projects/eeg_epileptiform_detection/EEG2Rep/Dataset/out_tuev/aaaaaaoy_00000001_channel_19_label_6_interval_id_2_unique_id_91
# channel: 20
# qq {14: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 2: {5: [[0.0, 2.0], [559.5, 563.5]]}, 7: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 20: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 13: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 16: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 12: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 3: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 5: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 10: {5: [[0.0, 2.0], [559.5, 563.5]]}, 9: {5: [[0.0, 2.0], [559.5, 563.5]]}, 17: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 8: {5: [[0.0, 2.0], [2.8, 6.8], [559.5, 563.5]]}, 15: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 6: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 19: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 0: {5: [[0.0, 2.0], [559.5, 563.5]], 4: [[6.9, 7.9]]}, 4: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[546.7, 551.7]]}, 21: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]]}, 1: {5: [[0.0, 2.0], [6.9, 7.9], [559.5, 563.5]]}, 18: {5: [[0.0, 2.0], [559.5, 563.5]], 6: [[2.7, 6.7], [542.3, 546.3], [546.6, 552.6]], 4: [[6.8, 7.8]]}, 11: {5: [[0.0, 2.0], [559.5, 563.5]]}}
# interval:  [0.0, 2.0] 5 0 93
# montage_list:  ['FP1-F7', 'F7-T3', 'T3-T5', 'T5-O1', 'FP2-F8', 'F8-T4', 'T4-T6', 'T6-O2', 'T3-C3', 'C3-CZ', 'CZ-C4', 'C4-T4', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 26
#      24 if len(interval) > 1:
#      25     print("interval: ",interval, label, index, unique_id)
# ---> 26     arr = convert_to_fft(interval[0], interval[1], 0.5, channel, 1, 96, 250, file_name + '.edf')
#      27     print("result_file_name: ",result_file_name)
#      28     np.save(result_file_name, arr)
#
# Cell In[71], line 31, in convert_to_fft(window_start, window_end, window_step, channel, fft_min_freq, fft_max_freq, sampling_frequency, file_path)
#      29 montage_list = re.split(';', montage)
#      30 print("montage_list: ", montage_list)
# ---> 31 print("montage_list[channel]: ", montage_list[channel])
#      32 electrode_list = re.split('-', montage_list[channel])
#      34 f = pyedflib.EdfReader(file_path)
#
# IndexError: list index out of range

# %%
print(os. getcwd() )
# Out:
# /home/eshuranov/projects/eeg_epileptiform_detection/ML_solution
