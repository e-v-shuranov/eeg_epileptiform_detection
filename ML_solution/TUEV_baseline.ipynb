# %% [markdown]
# # Extracting signals

# %%
import re
import os
import numpy as np
import pandas as pd

from scipy.signal import resample
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline

# from mne_features.feature_extraction import FeatureExtractor

# %%
import pyedflib

# %%
parameters = pd.read_csv('Dataset/parameters.csv', index_col=['parameter'])

# %%
def extract_signal(f, signal_labels, electrode_name, start, stop):

    tuh_label = [s for s in signal_labels if 'EEG ' + electrode_name + '-' in s]
    if len(tuh_label) > 1:
        print(tuh_label)
        exit('Multiple electrodes found with the same string! Abort')

    channel = signal_labels.index(tuh_label[0])
    signal = np.array(f.readSignal(channel))

    start, stop = float(start), float(stop)
    original_sample_frequency = f.getSampleFrequency(channel)
    original_start_index = int(np.floor(start * float(original_sample_frequency)))
    original_stop_index = int(np.floor(stop * float(original_sample_frequency)))

    seizure_signal = signal[original_start_index:original_stop_index]

    new_sample_frequency = int(parameters.loc['sampling_frequency']['value'])
    new_num_time_points = int(np.floor((stop - start) * new_sample_frequency))
    seizure_signal_resampled = resample(seizure_signal, new_num_time_points)

    return seizure_signal_resampled

def read_edfs_and_extract(edf_path, edf_start, edf_stop):

    f = pyedflib.EdfReader(edf_path)

    montage = str(parameters.loc['montage']['value'])
    montage_list = re.split(';', montage)
    signal_labels = f.getSignalLabels()
    x_data = []

    for i in montage_list:
        electrode_list = re.split('-', i)
        electrode_1 = electrode_list[0]
        extracted_signal_from_electrode_1 = extract_signal(f, signal_labels, electrode_name=electrode_1, start=edf_start, stop=edf_stop)
        electrode_2 = electrode_list[1]
        extracted_signal_from_electrode_2 = extract_signal(f, signal_labels, electrode_name=electrode_2, start=edf_start, stop=edf_stop)
        this_differential_output = extracted_signal_from_electrode_1-extracted_signal_from_electrode_2
        x_data.append(this_differential_output)

    f._close()
    del f

    x_data = np.array(x_data)

    return x_data

# %%
edf_path = '/home/eshuranov/projects/eeg_stud/Dataset/TUEV/tuev/edf/train/aaaaafop/aaaaafop_00000001.edf' # test file

# %%
test_file = read_edfs_and_extract(edf_path, 0, 1)

# %%
test_file.shape
# Out:
# (20, 250)

# %%
print(test_file)
# Out:
# [[-121. -120. -121. ...  116.  118.  119.]
#  [  -5.  -11.   -9. ...  -93. -106. -109.]
#  [   7.   13.   14. ...  -55.  -46.  -46.]
#  ...
#  [ -11.  -13.  -12. ...   24.   25.   23.]
#  [ -11.  -12.  -10. ...    8.    5.    6.]
#  [  -8.  -13.   -9. ...    9.    8.   11.]]

# %% [markdown]
# ## Applying FFT and post-processing

# %%
from utils_pipeline import Pipeline
from preprocessing_library import FFT, Slice, Magnitude, Log10

# %% [markdown]
# #### Applying preproccesing on labels

# %%
from label_preprocess import Preprocess
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from label_preprocess import Preprocess
#
# File ~/projects/eeg_stud/label_preprocess.py:3
#       1 import os
# ----> 3 class Preprocess:
#       4     def __init__(self):
#       5         self.result = {}
#
# File ~/projects/eeg_stud/label_preprocess.py:23, in Preprocess()
#      19             merged[-1][1] = segment[1]
#      21     return merged
# ---> 23 def labeling(self, intervals: list[list[float], int]):
#      24     """
#      25     :param intervals: list of intervals where intervals[i][0] - start intervals[i][1] - end intervals[i][2] - label
#      26     :return: labels - dictionary, keys - labels, values - intervals
#      27     """
#      28     labels = {}
#
# TypeError: 'type' object is not subscriptable

# %%
labels = Preprocess().apply()

# %%
def get_label(start, stop, channel, sampling_frequency, file_path):
    """
    params: start - start of the window, stop - end of the window, channel - channel nubmer, 
    sampling frequency - smapling frequency of edf file, file_path - file path to EDF file!!!
    return: labels which belongs to the window
    """
    global labels
    lst = file_path.split('/')
    
    file_name = lst[-1][:-4]
    result = []

    if channel not in labels[file_name]:
        return [None]
        
    possible_lables = labels[file_name][channel]
    for label in possible_lables:
        intervals = possible_lables[label]
        for interval in intervals:
            if interval[0] <= stop and interval[1] >= start or interval[1] >= start and interval[0] < stop:
                result.append(label)

    if not result:
        return [None]
    return result

# %% [markdown]
# #### FFT

# %%
def convert_to_fft_with_labels(window_length, window_step, fft_min_freq, fft_max_freq, sampling_frequency, file_path, file_length):
    """
    parmas:
    window_length - lenght of the interrval
    window_step - length of overlap
    sampling_frequency - frequency of the file
    file_path - path to the edf file
    file-length - length of the edf file
    return:
    pandas dataframe, with label, cahnnel number, FFT image and filename
    """
    time_series_data = read_edfs_and_extract(file_path, 0, file_length)
    
    pipeline = Pipeline([FFT(), Slice(fft_min_freq, fft_max_freq), Magnitude(), Log10()])
    
    label_start, label_step, label_stop = 0, window_step, window_length
    start, step = 0, int(np.floor(window_step * sampling_frequency))
    stop = start + int(np.floor(window_length * sampling_frequency))

    lst = file_path.split('/')
    file_name = lst[-1][:-4]
    fft_data = []

    while stop < time_series_data.shape[1]:
        signal_window = time_series_data[:, start:stop]
        fft_window = pipeline.apply(signal_window)

        for i in range(len(fft_window)):
            fft_data.append([get_label(label_start, label_stop, i, sampling_frequency, file_path), i, fft_window[i], label_start, file_name])
        
        start, stop = start + step, stop + step
        label_start, label_stop = label_start + label_step, label_stop + label_step

    return pd.DataFrame(fft_data, columns=['label', 'channel-number', 'FFT-image', 'window_start', 'file-name'])

# %%
def find_file_length(edf_path):
    f = pyedflib.EdfReader(edf_path)
    original_sample_frequency = f.getSampleFrequency(0)
    signal = np.array(f.readSignal(0))
    
    f._close()
    del f
    return len(signal) / original_sample_frequency

# %%
window_length = 5
window_step = window_length / 4
fft_min_freq = 1
fft_max_freq = 96
sampling_frequency = 250
file_path = '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaar/aaaaaaar_00000001.edf'
file_length = find_file_length(file_path)

# %%
result = convert_to_fft_with_labels(window_length, window_step, fft_min_freq, fft_max_freq,
                                    sampling_frequency, file_path, file_length)
result.head(25)
# Out:
#      label  channel-number                                          FFT-image  \
# 0      [6]               0  [4.353648527358219, 4.637707718247491, 4.00085...
# 1      [6]               1  [4.501154579595272, 3.9811983194273175, 4.0574...
# 2      [6]               2  [4.053145405319158, 3.9614527147490635, 3.5529...
# 3      [6]               3  [3.6639207606825597, 3.6409645058286917, 3.190...
# 4      [6]               4  [4.617176123115018, 4.303431852456283, 4.29354...
# 5   [None]               5  [4.561007835827728, 4.340348081221418, 4.09265...
# 6      [5]               6  [3.9356719940922273, 3.568082104961621, 3.5255...
# 7   [None]               7  [3.5882412124654914, 3.2515358459941455, 3.492...
# 8      [5]               8  [3.946554486834907, 4.0906360961089625, 3.4192...
# 9      [5]               9  [4.193737524936112, 3.656007687184383, 3.52556...
# 10  [None]              10  [3.8423026491820647, 3.423957302111611, 3.6041...
# 11  [None]              11  [3.829855727442037, 3.723836312261373, 3.60631...
# 12     [5]              12  [4.137402446842341, 4.383113923138421, 3.99066...
# 13     [5]              13  [4.068550223663454, 3.659789862766913, 3.69166...
# 14     [5]              14  [3.2089651836037296, 3.7292474864847414, 3.452...
# 15  [None]              15  [4.204376106759954, 3.9220244368839956, 3.6630...
# 16     [6]              16  [4.119347609422519, 4.363250525447883, 3.96455...
# 17     [6]              17  [3.9019022558590954, 3.7770619403511896, 3.221...
# 18     [6]              18  [3.6112124053260053, 3.4349741924030126, 3.008...
# 19     [6]              19  [3.200132533337599, 3.2757550868378975, 3.3672...
# 20     [6]               0  [4.591507456320479, 4.532644410319391, 4.24240...
# 21     [6]               1  [4.506212546007487, 4.087307989689811, 3.92772...
# 22     [6]               2  [4.128144021122139, 3.918728175667948, 3.74123...
# 23     [6]               3  [3.5175809719496005, 3.4477646940258753, 3.375...
# 24     [6]               4  [4.63336992685964, 4.156952953193077, 3.921417...
#
#     window_start          file-name
# 0           0.00  aaaaaaar_00000001
# 1           0.00  aaaaaaar_00000001
# 2           0.00  aaaaaaar_00000001
# 3           0.00  aaaaaaar_00000001
# 4           0.00  aaaaaaar_00000001
# 5           0.00  aaaaaaar_00000001
# 6           0.00  aaaaaaar_00000001
# 7           0.00  aaaaaaar_00000001
# 8           0.00  aaaaaaar_00000001
# 9           0.00  aaaaaaar_00000001
# 10          0.00  aaaaaaar_00000001
# 11          0.00  aaaaaaar_00000001
# 12          0.00  aaaaaaar_00000001
# 13          0.00  aaaaaaar_00000001
# 14          0.00  aaaaaaar_00000001
# 15          0.00  aaaaaaar_00000001
# 16          0.00  aaaaaaar_00000001
# 17          0.00  aaaaaaar_00000001
# 18          0.00  aaaaaaar_00000001
# 19          0.00  aaaaaaar_00000001
# 20          1.25  aaaaaaar_00000001
# 21          1.25  aaaaaaar_00000001
# 22          1.25  aaaaaaar_00000001
# 23          1.25  aaaaaaar_00000001
# 24          1.25  aaaaaaar_00000001

# %%
result.shape
# Out:
# (25540, 5)

# %% [markdown]
# ### Analysing a separate file

# %%
import dill as pickle
import warnings

# %%
test_path = 'aaaaaaar_00000001.edf'

# %%
import pyedflib
import numpy as np

f = pyedflib.EdfReader(test_path)
original_sample_frequency = f.getSampleFrequency(2)
signal = np.array(f.readSignal(2))
print(f'raw signal by channel 0: {signal}, length of the signal: {len(signal)}')
print(f'original sample freqauency: {original_sample_frequency}')
print(f'length of the signal in seconds: {len(signal) / original_sample_frequency}')
f._close()
del f
# Out:
# raw signal by channel 0: [-58. -62. -57. ...   0.   0.   0.], length of the signal: 399500
# original sample freqauency: 250.0
# length of the signal in seconds: 1598.0

# %% [markdown]
# # Train and Validation sets

# %% [markdown]
# ### Getting file paths

# %%
import os

file_paths = []
for dirpath, dirnames, filenames in os.walk("/Users/konstantin/Desktop/TUEV_data/edf/train"):
    for filename in sorted(list(filenames)):
        if filename.endswith('.edf'):
            file_paths.append(os.path.join(dirpath, filename))

# %%
file_paths
# Out:
# ['/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaablw/aaaaablw_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaevo/aaaaaevo_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeyk/aaaaaeyk_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafoe/aaaaafoe_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadlg/aaaaadlg_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabji/aaaaabji_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadoo/aaaaadoo_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaezj/aaaaaezj_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacvq/aaaaacvq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaboq/aaaaaboq_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaezm/aaaaaezm_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadoa/aaaaadoa_00000006.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadea/aaaaadea_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabju/aaaaabju_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafcu/aaaaafcu_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabfy/aaaaabfy_00000007.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaavn/aaaaaavn_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaazl/aaaaaazl_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaffm/aaaaaffm_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabfp/aaaaabfp_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabfp/aaaaabfp_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabom/aaaaabom_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafop/aaaaafop_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeur/aaaaaeur_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeuh/aaaaaeuh_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabop/aaaaabop_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabop/aaaaabop_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabop/aaaaabop_00000004.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafit/aaaaafit_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaur/aaaaaaur_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaur/aaaaaaur_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaur/aaaaaaur_00000004.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabel/aaaaabel_00000013.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacvy/aaaaacvy_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacuq/aaaaacuq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaavs/aaaaaavs_00000006.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaesj/aaaaaesj_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaesm/aaaaaesm_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafcs/aaaaafcs_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaug/aaaaaaug_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadjd/aaaaadjd_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadik/aaaaadik_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeni/aaaaaeni_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacko/aaaaacko_00000006.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacko/aaaaacko_00000007.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaahm/aaaaaahm_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadrv/aaaaadrv_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaachi/aaaaachi_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacnb/aaaaacnb_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaadz/aaaaaadz_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadrd/aaaaadrd_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadrd/aaaaadrd_00000005.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadxv/aaaaadxv_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaehl/aaaaaehl_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacks/aaaaacks_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacgq/aaaaacgq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaads/aaaaaads_00000009.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaems/aaaaaems_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaadt/aaaaaadt_00000010.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaadn/aaaaaadn_00000004.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabqo/aaaaabqo_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadqq/aaaaadqq_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaehv/aaaaaehv_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabtw/aaaaabtw_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadxl/aaaaadxl_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaadg/aaaaaadg_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaadg/aaaaaadg_00000008.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabqs/aaaaabqs_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacgy/aaaaacgy_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaahp/aaaaaahp_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacmk/aaaaacmk_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadxw/aaaaadxw_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaegi/aaaaaegi_00000004.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacnc/aaaaacnc_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacml/aaaaacml_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabrr/aaaaabrr_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabym/aaaaabym_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaecu/aaaaaecu_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeel/aaaaaeel_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacon/aaaaacon_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadsh/aaaaadsh_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabyj/aaaaabyj_00000007.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadpg/aaaaadpg_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacer/aaaaacer_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabvg/aaaaabvg_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaefj/aaaaaefj_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeee/aaaaaeee_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeee/aaaaaeee_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeee/aaaaaeee_00000004.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeee/aaaaaeee_00000005.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadst/aaaaadst_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadst/aaaaadst_00000005.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaa
00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadvi/aaaaadvi_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaefs/aaaaaefs_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadsv/aaaaadsv_00000005.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadsv/aaaaadsv_00000011.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabyt/aaaaabyt_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacjf/aaaaacjf_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeer/aaaaaeer_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadvu/aaaaadvu_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadyv/aaaaadyv_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadsd/aaaaadsd_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacjz/aaaaacjz_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeie/aaaaaeie_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaet/aaaaaaet_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaof/aaaaaaof_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafmb/aaaaafmb_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacww/aaaaacww_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafai/aaaaafai_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafai/aaaaafai_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabbu/aaaaabbu_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaxp/aaaaaaxp_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafku/aaaaafku_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaewi/aaaaaewi_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafgy/aaaaafgy_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaws/aaaaaaws_00000010.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadni/aaaaadni_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabgq/aaaaabgq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabgq/aaaaabgq_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadbw/aaaaadbw_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabhu/aaaaabhu_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabbn/aaaaabbn_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaactm/aaaaactm_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabgx/aaaaabgx_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaetz/aaaaaetz_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafdw/aaaaafdw_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadnh/aaaaadnh_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacwx/aaaaacwx_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafnb/aaaaafnb_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaaxq/aaaaaaxq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaadgr/aaaaadgr_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaacwq/aaaaacwq_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaexb/aaaaaexb_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafmv/aaaaafmv_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafmv/aaaaafmv_00000002.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafgm/aaaaafgm_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeqc/aaaaaeqc_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaabba/aaaaabba_00000003.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaafka/aaaaafka_00000001.edf',
#  '/Users/konstantin/Desktop/TUEV_data/edf/train/aaaaaeqd/aaaaaeqd_00000001.edf']

# %% [markdown]
# ### Apllying preprocess transformation

# %%
window_length = 5
window_step = window_length / 4
fft_min_freq = 1
fft_max_freq = 96
sampling_frequency = 250
file_path = file_paths[0]
file_length = find_file_length(file_path)

# %%
df = convert_to_fft_with_labels(window_length, window_step, fft_min_freq, fft_max_freq, sampling_frequency, file_path, file_length)
df.head()
# Out:
#     label  channel-number                                          FFT-image  \
# 0  [None]               0  [3.5651459841051847, 4.054554959153428, 3.9608...
# 1  [None]               1  [4.297497666425236, 3.899223790290856, 3.59796...
# 2  [None]               2  [3.8161823051675143, 2.208106576150998, 2.8847...
# 3  [None]               3  [2.7846219695132572, 2.8531217438387517, 2.946...
# 4  [None]               4  [4.352776568267279, 3.7358987357430027, 3.7028...
#
#    window_start          file-name
# 0           0.0  aaaaablw_00000001
# 1           0.0  aaaaablw_00000001
# 2           0.0  aaaaablw_00000001
# 3           0.0  aaaaablw_00000001
# 4           0.0  aaaaablw_00000001

# %%
for i in range(1, len(file_paths)):
    file_path = file_paths[i]
    file_length = find_file_length(file_path)
    
    tmp_data_frame = convert_to_fft_with_labels(window_length, window_step, fft_min_freq, fft_max_freq, sampling_frequency, file_path, file_length)
    df = pd.concat([df, tmp_data_frame])

# %%
df.shape
# Out:
# (5770360, 5)

# %%
df.to_csv('data.csv')

# %% [markdown]
# ### Spliting data in train and validation sets

# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv('data.csv', sep=',')
df = df.reset_index()

# %%
X = df[['FFT-image', 'window_start', 'channel-number']]
X
# Out:
#                                                  FFT-image  window_start  \
# 0        [3.56514598 4.05455496 3.96080639 3.88191954 3...          0.00
# 1        [4.29749767 3.89922379 3.59796984 3.37093156 3...          0.00
# 2        [3.81618231 2.20810658 2.88477519 2.59044162 2...          0.00
# 3        [ 2.78462197  2.85312174  2.94692202  3.012070...          0.00
# 4        [4.35277657 3.73589874 3.70289783 2.99328087 3...          0.00
# ...                                                    ...           ...
# 5770355  [2.98655675 2.63212274 2.51678878 2.69555511 2...       1361.25
# 5770356  [3.01657186 2.97345611 2.71332353 2.98604653 2...       1361.25
# 5770357  [3.01137721 2.99581212 2.7047019  2.05343629 1...       1361.25
# 5770358  [3.10698782 2.84377458 3.19318984 2.20565263 2...       1361.25
# 5770359  [2.77933966 3.10120461 2.3367045  2.29402621 2...       1361.25
#
#          channel-number
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# ...                 ...
# 5770355              15
# 5770356              16
# 5770357              17
# 5770358              18
# 5770359              19
#
# [5770360 rows x 3 columns]

# %%
X = X.rename(columns={'FFT-image': 'FFT_image'})
X
# Out:
#                                                  FFT_image  window_start  \
# 0        [3.56514598 4.05455496 3.96080639 3.88191954 3...          0.00
# 1        [4.29749767 3.89922379 3.59796984 3.37093156 3...          0.00
# 2        [3.81618231 2.20810658 2.88477519 2.59044162 2...          0.00
# 3        [ 2.78462197  2.85312174  2.94692202  3.012070...          0.00
# 4        [4.35277657 3.73589874 3.70289783 2.99328087 3...          0.00
# ...                                                    ...           ...
# 5770355  [2.98655675 2.63212274 2.51678878 2.69555511 2...       1361.25
# 5770356  [3.01657186 2.97345611 2.71332353 2.98604653 2...       1361.25
# 5770357  [3.01137721 2.99581212 2.7047019  2.05343629 1...       1361.25
# 5770358  [3.10698782 2.84377458 3.19318984 2.20565263 2...       1361.25
# 5770359  [2.77933966 3.10120461 2.3367045  2.29402621 2...       1361.25
#
#          channel-number
# 0                     0
# 1                     1
# 2                     2
# 3                     3
# 4                     4
# ...                 ...
# 5770355              15
# 5770356              16
# 5770357              17
# 5770358              18
# 5770359              19
#
# [5770360 rows x 3 columns]

# %%
X['FFT_image'] = X['FFT_image'].str.replace('\n', '')

# %%
X['FFT_image'] = X.FFT_image.str[1:-1].replace('  ', ' ')

# %%
arr = []

# %%
for string in X.FFT_image:
    arr.append(list(map(float, string.split())))

# %%
len(arr)

# %%
tmp = pd.DataFrame(arr, columns = [f'FFT_image_signal_{index}' for index in range(96)])

# %%
# tmp = pd.DataFrame(X.FFT_image.str.split(), columns = [f'FFT_image_signal_{index}' for index in range(96)])

# %%
tmp.head()

# %%
Y = df[['label']]
Y.head()
# Out:
#     label
# 0  [None]
# 1  [None]
# 2  [None]
# 3  [None]
# 4  [None]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, random_state=42)

# %%
y_train.head()
# Out:
#         label
# 10995  [None]
# 7178   [None]
# 27063  [None]
# 3193   [None]
# 1098   [None]

# %%
X_train.head()
# Out:
#                                                FFT-image  window_start  \
# 10995  [3.943334931850202, 3.80215277060562, 3.697599...        686.25
# 7178   [3.212959647964134, 3.672813773919944, 3.38470...        447.50
# 27063  [3.152114161776472, 3.1408470899256153, 2.5271...       1691.25
# 3193   [2.6590546898748784, 2.7028677099069056, 2.370...        198.75
# 1098   [2.844020507837268, 3.238936133838194, 3.02474...         67.50
#
#        channel-number
# 10995              15
# 7178               18
# 27063               3
# 3193               13
# 1098               18

# %% [markdown]
# ### Model training

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier(n_estimators=100, loss='log_loss', learning_rate=1.0, random_state=42).fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/kv/2gtnhpcs6jd_s7t430044src0000gn/T/ipykernel_27556/1070463451.py in ?()
# ----> 1 clf = GradientBoostingClassifier(n_estimators=100, loss='log_loss', learning_rate=1.0, random_state=42).fit(X_train, y_train)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/ensemble/_gb.py in ?(self, X, y, sample_weight, monitor)
#     655         # Check input
#     656         # Since check_array converts both X and y to the same dtype, but the
#     657         # trees use different types for X and y, checking them separately.
#     658
# --> 659         X, y = self._validate_data(
#     660             X, y, accept_sparse=["csr", "csc", "coo"], dtype=DTYPE, multi_output=True
#     661         )
#     662         sample_weight_is_none = sample_weight is None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1297         raise ValueError(
#    1298             f"{estimator_name} requires y to be passed, but the target y is None"
#    1299         )
#    1300
# -> 1301     X = check_array(
#    1302         X,
#    1303         accept_sparse=accept_sparse,
#    1304         accept_large_sparse=accept_large_sparse,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013             except ComplexWarning as complex_warning:
# -> 1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#    1017
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: setting an array element with a sequence.

# %%
clf.score(X_test, y_test)
